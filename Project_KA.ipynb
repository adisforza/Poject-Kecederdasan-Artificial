# %% [markdown]
# Room Occupancy Estimation

# %% [markdown]
# # load data

# %%
# !pip install ucimlrepo

# %%
from ucimlrepo import fetch_ucirepo

# fetch dataset
room_occupancy_estimation = fetch_ucirepo(id=864)

# data (as pandas dataframes)
X = room_occupancy_estimation.data.features
y = room_occupancy_estimation.data.targets

# metadata
print(room_occupancy_estimation.metadata)

# variable information
print(room_occupancy_estimation.variables)
# Out:
# {'uci_id': 864, 'name': 'Room Occupancy Estimation', 'repository_url': 'https://archive.ics.uci.edu/dataset/864/room+occupancy+estimation', 'data_url': 'https://archive.ics.uci.edu/static/public/864/data.csv', 'abstract': 'Data set for estimating the precise number of occupants in a room using multiple non-intrusive environmental sensors like temperature, light, sound, CO2 and PIR.', 'area': 'Computer Science', 'tasks': ['Classification'], 'characteristics': ['Multivariate', 'Time-Series'], 'num_instances': 10129, 'num_features': 18, 'feature_types': ['Real'], 'demographics': [], 'target_col': ['Room_Occupancy_Count'], 'index_col': None, 'has_missing_values': 'no', 'missing_values_symbol': None, 'year_of_dataset_creation': 2018, 'last_updated': 'Wed Aug 16 2023', 'dataset_doi': '10.24432/C5P605', 'creators': ['Adarsh Pal Singh', 'Sachin Chaudhari'], 'intro_paper': {'ID': 275, 'type': 'NATIVE', 'title': 'Machine Learning-Based Occupancy Estimation Using Multivariate Sensor Nodes', 'au
# ...

# %% [markdown]
# # EDA

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
X.isna().sum()
# Out:
# Date            0
# Time            0
# S1_Temp         0
# S2_Temp         0
# S3_Temp         0
# S4_Temp         0
# S1_Light        0
# S2_Light        0
# S3_Light        0
# S4_Light        0
# S1_Sound        0
# S2_Sound        0
# S3_Sound        0
# S4_Sound        0
# S5_CO2          0
# S5_CO2_Slope    0
# S6_PIR          0
# S7_PIR          0
# dtype: int64

# %%
X
# Out:
#              Date      Time  S1_Temp  S2_Temp  S3_Temp  S4_Temp  S1_Light  \
# 0      2017/12/22  10:49:41    24.94    24.75    24.56    25.38       121
# 1      2017/12/22  10:50:12    24.94    24.75    24.56    25.44       121
# 2      2017/12/22  10:50:42    25.00    24.75    24.50    25.44       121
# 3      2017/12/22  10:51:13    25.00    24.75    24.56    25.44       121
# 4      2017/12/22  10:51:44    25.00    24.75    24.56    25.44       121
# ...           ...       ...      ...      ...      ...      ...       ...
# 10124  2018/01/11  08:58:07    25.06    25.13    24.69    25.31         6
# 10125  2018/01/11  08:58:37    25.06    25.06    24.69    25.25         6
# 10126  2018/01/11  08:59:08    25.13    25.06    24.69    25.25         6
# 10127  2018/01/11  08:59:39    25.13    25.06    24.69    25.25         6
# 10128  2018/01/11  09:00:09    25.13    25.06    24.69    25.25         6
#
#        S2_Light  S3_Light  S4_Light  S1_Sound  S2_Sound  S3_Sound  S4_Sound  \
# ...

# %%
y
# Out:
#        Room_Occupancy_Count
# 0                         1
# 1                         1
# 2                         1
# 3                         1
# 4                         1
# ...                     ...
# 10124                     0
# 10125                     0
# 10126                     0
# 10127                     0
# 10128                     0
#
# [10129 rows x 1 columns]

# %%
y['Room_Occupancy_Count'].unique()
# Out:
# array([1, 2, 3, 0])

# %%
y.isna().sum() #cek jumlah nilai kosong (NaN)
# Out:
# Room_Occupancy_Count    0
# dtype: int64

# %%
y.value_counts()
# Out:
# Room_Occupancy_Count
# 0                       8228
# 2                        748
# 3                        694
# 1                        459
# Name: count, dtype: int64

# %%
X['Datetime'] = pd.to_datetime(X['Date'] + " " + X['Time'])


# ekstrak fitur waktu
X['Hour']   = X['Datetime'].dt.hour
X['Minute'] = X['Datetime'].dt.minute
X['Second'] = X['Datetime'].dt.second

X['day']    = X['Datetime'].dt.day
X['month']  = X['Datetime'].dt.month
X['year']   = X['Datetime'].dt.year


X = X.drop(columns=['Datetime'])
X = X.drop(columns=['Date', 'Time'])

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42, stratify = y )
#stratify biar split per label
print (X_train.shape, y_train.shape)
print (X_test.shape, y_test.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1245771519.py in <cell line: 0>()
#       2
#       3 X_train, X_test, y_train, y_test = train_test_split(
# ----> 4     X, y, test_size=0.3, random_state=42, stratify = y )
#       5 #stratify biar split per label
#       6 print (X_train.shape, y_train.shape)
#
# NameError: name 'X' is not defined

# %%
y_test.value_counts()

# %%
df = pd.concat([X_train, y_train], axis=1)
df.head()
# Out:
#       S1_Temp  S2_Temp  S3_Temp  S4_Temp  S1_Light  S2_Light  S3_Light  \
# 6656    25.44    25.44    25.06    25.94         0         0         0
# 1624    25.38    25.31    24.88    25.81         0         0         0
# 2866    25.44    25.31    25.06    25.88       124        37        70
# 4691    25.31    25.31    24.75    25.63         0         0         0
# 6078    25.44    25.44    25.44    26.13         8        10        41
#
#       S4_Light  S1_Sound  S2_Sound  ...  S5_CO2_Slope  S6_PIR  S7_PIR  Hour  \
# 6656         0      0.08      0.05  ...     -0.107692       0       0    20
# 1624         0      0.07      0.04  ...      0.000000       0       0     1
# 2866        50      0.09      0.05  ...      0.219231       0       0    12
# 4691         0      0.06      0.05  ...      0.000000       0       0     3
# 6078        30      0.08      0.06  ...      0.000000       0       0    15
#
#       Minute  Second  day  month  year  Room_Occupancy_Count
# ...

# %%
df['Room_Occupancy_Count'].value_counts()
# Out:
# Room_Occupancy_Count
# 0    5759
# 2     524
# 3     486
# 1     321
# Name: count, dtype: int64

# %%
df
# Out:
#       S1_Temp  S2_Temp  S3_Temp  S4_Temp  S1_Light  S2_Light  S3_Light  \
# 6656    25.44    25.44    25.06    25.94         0         0         0
# 1624    25.38    25.31    24.88    25.81         0         0         0
# 2866    25.44    25.31    25.06    25.88       124        37        70
# 4691    25.31    25.31    24.75    25.63         0         0         0
# 6078    25.44    25.44    25.44    26.13         8        10        41
# ...       ...      ...      ...      ...       ...       ...       ...
# 5986    25.44    25.44    25.44    26.13        14        18        70
# 4095    25.50    25.50    25.13    25.75         0         0         0
# 3314    26.00    26.81    25.50    26.31       119        24        38
# 8359    25.94    26.31    25.81    25.94       142       226         6
# 1386    25.44    25.44    25.00    25.75         0         0         0
#
#       S4_Light  S1_Sound  S2_Sound  ...  S5_CO2_Slope  S6_PIR  S7_PIR  Hour  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7090 entries, 6656 to 1386
# Data columns (total 23 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   S1_Temp               7090 non-null   float64
#  1   S2_Temp               7090 non-null   float64
#  2   S3_Temp               7090 non-null   float64
#  3   S4_Temp               7090 non-null   float64
#  4   S1_Light              7090 non-null   int64
#  5   S2_Light              7090 non-null   int64
#  6   S3_Light              7090 non-null   int64
#  7   S4_Light              7090 non-null   int64
#  8   S1_Sound              7090 non-null   float64
#  9   S2_Sound              7090 non-null   float64
#  10  S3_Sound              7090 non-null   float64
#  11  S4_Sound              7090 non-null   float64
#  12  S5_CO2                7090 non-null   int64
#  13  S5_CO2_Slope          7090 non-null   float64
#  14  S6_PIR                7090 non-null   int64
# ...

# %% [markdown]
# # PRE PROCESSING

# %%
df_0, df_1, df_2, df_3 = (g for _,g in df.groupby('Room_Occupancy_Count'))

# %% [markdown]
# Hapus outlier

# %%
from sklearn.ensemble import IsolationForest

df_clear=[]
def clear_outlire (data):
  df_outlire = data.drop("Room_Occupancy_Count",axis=1)

  iso = IsolationForest(
      n_estimators= 100,
      contamination= "auto",
      random_state= 42
  )

  iso.fit(df_outlire)
  df_outlire['ISO_Outlier'] = iso.predict(df_outlire)
  df_outlire['ISO_Outlier'] = df_outlire['ISO_Outlier'].map({1: 0, -1:  1})

  print (df_outlire['ISO_Outlier'].value_counts()
)
  return df_clear.append(df_outlire)


list_class = (df_0,df_1,df_2,df_3)
for v in list_class:
  clear_outlire(data = v)

df_cleared= pd.concat(df_clear)
# Out:
# ISO_Outlier
# 0    4561
# 1    1198
# Name: count, dtype: int64
# ISO_Outlier
# 0    268
# 1     53
# Name: count, dtype: int64
# ISO_Outlier
# 0    347
# 1    177
# Name: count, dtype: int64
# ISO_Outlier
# 0    290
# 1    196
# Name: count, dtype: int64

# %%
df_cleared
# Out:
#       S1_Temp  S2_Temp  S3_Temp  S4_Temp  S1_Light  S2_Light  S3_Light  \
# 6656    25.44    25.44    25.06    25.94         0         0         0
# 1624    25.38    25.31    24.88    25.81         0         0         0
# 4691    25.31    25.31    24.75    25.63         0         0         0
# 6078    25.44    25.44    25.44    26.13         8        10        41
# 2045    25.13    25.13    24.56    25.50         0         0         0
# ...       ...      ...      ...      ...       ...       ...       ...
# 821     26.31    26.44    26.00    26.44       149       234       178
# 8108    25.56    26.13    25.44    25.69        10        10        51
# 336     26.19    27.25    26.06    26.38       163       251       272
# 288     26.13    27.06    26.00    26.31       164       255       278
# 248     26.00    27.88    25.75    26.25       165       254       272
#
#       S4_Light  S1_Sound  S2_Sound  ...  S5_CO2_Slope  S6_PIR  S7_PIR  Hour  \
# ...

# %%
df
# Out:
#       S1_Temp  S2_Temp  S3_Temp  S4_Temp  S1_Light  S2_Light  S3_Light  \
# 6656    25.44    25.44    25.06    25.94         0         0         0
# 1624    25.38    25.31    24.88    25.81         0         0         0
# 2866    25.44    25.31    25.06    25.88       124        37        70
# 4691    25.31    25.31    24.75    25.63         0         0         0
# 6078    25.44    25.44    25.44    26.13         8        10        41
# ...       ...      ...      ...      ...       ...       ...       ...
# 5986    25.44    25.44    25.44    26.13        14        18        70
# 4095    25.50    25.50    25.13    25.75         0         0         0
# 3314    26.00    26.81    25.50    26.31       119        24        38
# 8359    25.94    26.31    25.81    25.94       142       226         6
# 1386    25.44    25.44    25.00    25.75         0         0         0
#
#       S4_Light  S1_Sound  S2_Sound  ...  S5_CO2_Slope  S6_PIR  S7_PIR  Hour  \
# ...

# %%
df = df[df_cleared['ISO_Outlier']==0].copy()
df
# Out:
# /tmp/ipython-input-1917754465.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df = df[df_cleared['ISO_Outlier']==0].copy()
#       S1_Temp  S2_Temp  S3_Temp  S4_Temp  S1_Light  S2_Light  S3_Light  \
# 6656    25.44    25.44    25.06    25.94         0         0         0
# 1624    25.38    25.31    24.88    25.81         0         0         0
# 2866    25.44    25.31    25.06    25.88       124        37        70
# 4691    25.31    25.31    24.75    25.63         0         0         0
# 6078    25.44    25.44    25.44    26.13         8        10        41
# ...       ...      ...      ...      ...       ...       ...       ...
# 4827    25.19    25.25    24.63    25.50         0         0         0
# 1925    25.19    25.25    24.69    25.56         0         0         0
# 4095    25.50    25.50    25.13    25.75         0         0         0
# 3314    26.00    26.81    25.50    26.31       119        24        38
# ...

# %%
df['Room_Occupancy_Count'].value_counts()
# Out:
# Room_Occupancy_Count
# 0    4561
# 2     347
# 3     290
# 1     268
# Name: count, dtype: int64

# %% [markdown]
# ##standarisasi

# %%
X_train = df.drop("Room_Occupancy_Count",axis=1)
y_train = df['Room_Occupancy_Count'].copy()

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# # Random Forest Tanpa PCA

# %%
import math
import numpy as np
from random import seed, randrange
seed(42)

# %%
def test_split(index, value, dataset):
    left, right = [], []
    for row in dataset:
        if row[index] < value:
            left.append(row)
        else:
            right.append(row)
    return left, right

def gini_index(groups, class_values):
    n_instances = float(sum(len(group) for group in groups))
    gini = 0.0
    for group in groups:
        size = float(len(group))
        if size == 0: continue
        score = 0.0
        for class_val in class_values:
            p = [row[-1] for row in group].count(class_val) / size
            score += p * p
        gini += (1.0 - score) * (size / n_instances)
    return gini

def get_split(dataset, n_features):
    class_values = list(set(row[-1] for row in dataset))
    b_index, b_value, b_score, b_groups = 999, 999, 999, None
    features = []
    while len(features) < n_features:
        index = randrange(len(dataset[0]) - 1)
        if index not in features:
            features.append(index)
    for index in features:
        for row in dataset:
            groups = test_split(index, row[index], dataset)
            gini = gini_index(groups, class_values)
            if gini < b_score:
                b_index, b_value, b_score, b_groups = index, row[index], gini, groups
    return {'index': b_index, 'value': b_value, 'groups': b_groups}

def to_terminal(group):d
    outcomes = [row[-1] for row in group]
    return max(set(outcomes), key=outcomes.count)
3
def split(node, max_depth, min_size, n_features, depth):
    left, right = node['groups']
    del node['groups']
    if not left or not right:
        node['left'] = node['right'] = to_terminal(left + right)
        return
    if depth >= max_depth:
        node['left'], node['right'] = to_terminal(left), to_terminal(right)
        return

    if len(left) <= min_size:
        node['left'] = to_terminal(left)
    else:
        node['left'] = get_split(left, n_features)
        split(node['left'], max_depth, min_size, n_features, depth + 1)

    if len(right) <= min_size:
        node['right'] = to_terminal(right)
    else:
        node['right'] = get_split(right, n_features)
        split(node['right'], max_depth, min_size, n_features, depth + 1)


def build_tree(train, max_depth, min_size, n_features):
    root = get_split(train, n_features)
    split(root, max_depth, min_size, n_features, 1)
    return root

def predict(node, row):
    if row[node['index']] < node['value']:
        if isinstance(node['left'], dict):
            return predict(node['left'], row)
        else:
            return node['left']
    else:
        if isinstance(node['right'], dict):
            return predict(node['right'], row)
        else:
            return node['right']

def subsample(dataset, ratio):
    sample = []
    n_sample = round(len(dataset) * ratio)
    while len(sample) < n_sample:
        index = randrange(len(dataset))
        sample.append(dataset[index])
    return sample

def bagging_predict(trees, row):
    predictions = [predict(tree, row) for tree in trees]
    return max(set(predictions), key=predictions.count)

def train_random_forest(X_train, y_train, max_depth=10, min_size=1,sample_size=1.0, n_trees=10, n_features=None):
    train = [list(X_train[i]) + [y_train[i]] for i in range(len(X_train))]
    trees = []

    for i in range(n_trees):
        sample = subsample(train, sample_size)
        tree = build_tree(sample, max_depth, min_size, n_features)
        trees.append(tree)
    return trees

def test_random_forest(trees , X_test):
    predictions = [bagging_predict(trees, row) for row in X_test]
    return predictions

def accuracy_metric(actual, predicted):
	correct = 0
	for i in range(len(actual)):
		if actual[i][0] == predicted[i]:
			correct += 1
	return correct / float(len(actual)) * 100.0

# %%
n_features = int(math.sqrt(len(X_train[0]))) #sqrt mengurangi komputasi
print("Features used:", n_features)
# Out:
# Features used: 4

# %%
y_train = y_train.values
y_test = y_test.values

# %%
train = train_random_forest(X_train,
                      y_train,
                      max_depth=10,
                      n_features=n_features)

# %%
import pickle
from sklearn.metrics import f1_score,precision_score,recall_score

# %%
with open ("train.pkl","wb") as f:
  pickle.dump(train,f)

# %%
trees= pickle.load(open('train.pkl',"rb"))
y_pred = test_random_forest(trees , X_test)

# %%
print(f1_score(y_test, y_pred, average='macro'))
print(precision_score(y_test, y_pred, average='macro'))
print(recall_score(y_test,y_pred, average='macro'))
print(accuracy_metric(y_test, y_pred))
# Out:
# 0.9234328149165698
# 0.9253566992865231
# 0.9267377361146347
# 97.82823297137216

# %% [markdown]
# # PCA

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components = 0.95)
pca_train=pca.fit_transform(X_train)
print(pca.components_.shape)
# Out:
# (13, 22)

# %%
pca_test = pca.transform(X_test)

# %% [markdown]
# #Random Forest Dengan PCA

# %%
n_features = int(math.sqrt(len(pca_train[0]))) #sqrt mengurangi komputasi
print("Features used:", n_features)
# Out:
# Features used: 3

# %%
train_PCA = train_random_forest(pca_train,
                      y_train,
                      max_depth=10,
                      n_features=n_features)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-108899731.py in <cell line: 0>()
# ----> 1 train_PCA = train_random_forest(pca_train,
#       2                       y_train,
#       3                       max_depth=10,
#       4                       n_features=n_features)
#
# /tmp/ipython-input-3410116775.py in train_random_forest(X_train, y_train, max_depth, min_size, sample_size, n_trees, n_features)
#      99     for i in range(n_trees):
#     100         sample = subsample(train, sample_size)
# --> 101         tree = build_tree(sample, max_depth, min_size, n_features)
#     102         trees.append(tree)
#     103     return trees
#
# /tmp/ipython-input-3410116775.py in build_tree(train, max_depth, min_size, n_features)
#      65
#      66 def build_tree(train, max_depth, min_size, n_features):
# ---> 67     root = get_split(train, n_features)
# ...

# %%
with open ("PCA_train.pkl","wb") as f:
  pickle.dump(train_PCA,f)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2901275391.py in <cell line: 0>()
#       1 with open ("PCA_train.pkl","wb") as f:
# ----> 2   pickle.dump(train_PCA,f)
#
# NameError: name 'train_PCA' is not defined

# %%
trees= pickle.load(open('PCA_train.pkl',"rb"))
pca_pred = test_random_forest(trees , pca_test)

# %%
from sklearn.metrics import f1_score,precision_score,recall_score

print(f1_score(y_test, pca_pred, average='macro'))
print(precision_score(y_test, pca_pred, average='macro'))
print(recall_score(y_test,pca_pred, average='macro'))
print(accuracy_metric(y_test, pca_pred))
# Out:
# 0.8122690426816471
# 0.7721404496735048
# 0.8845935252288435
# 92.39881539980257
